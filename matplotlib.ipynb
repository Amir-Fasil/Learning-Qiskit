# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

(fig , ax) = plt.subplots(2,2)
print(type(fig))
print(ax)
ax[0,0].set_title("sample_plot")
ax[0,0].set_xlabel("x_axis")
ax[0,0].set_ylabel("y_axis")
ax[0,0].plot(x,y)
plt.show()
# Out:
# <class 'matplotlib.figure.Figure'>
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %%
fog = plt.figure()
plt.show()
