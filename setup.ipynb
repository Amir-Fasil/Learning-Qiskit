# %%
import qiskit

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
    channel="ibm_quantum_platform",
    token = "0F7VRHO0M3wJTC2G6UBEw-znoulm9YvaLikayITWunkZ",
    overwrite=True
)

# %%
service = QiskitRuntimeService()
backends = service.backend(name = "ibm_torino")
# Out:
# qiskit_runtime_service.__init__:WARNING:2025-12-27 17:35:32,655: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2025-12-27 17:35:32,655: Using instance: open-instance, plan: open

# %%
print(backends)
print(backends.num_qubits)
# Out:
# <IBMBackend('ibm_torino')>
# 133
